# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
US_Var_data = pd.read_csv("AMF_US-Var_BASE_HH_9-1.csv", comment = "#")
US_Ton_data = pd.read_csv("AMF_US-Ton_BASE_HH_9-1.csv", comment = "#")

# %%
US_Var_nan = US_Var_data.replace("-9999", np.nan)
US_Ton_nan = US_Ton_data.replace("-9999", np.nan)
US_Var_nan.dtypes
# Out:
# TIMESTAMP_START      int64
# TIMESTAMP_END        int64
# USTAR              float64
# TA                 float64
# WD                 float64
# WS                 float64
# NEE_PI             float64
# FC                 float64
# SC                 float64
# H                  float64
# SH                 float64
# LE                 float64
# SLE                float64
# G                  float64
# TS_1               float64
# TS_2               float64
# P                  float64
# RH                 float64
# PA                 float64
# CO2_1              float64
# CO2_2              float64
# VPD_PI             float64
# SWC_1              float64
# SWC_2              float64
# NETRAD             float64
# PPFD_IN            float64
# SW_IN              float64
# SW_DIF             float64
# PPFD_OUT           float64
# SW_OUT             float64
# LW_IN              float64
# LW_OUT             float64
# H2O                float64
# RECO_PI            float64
# APAR               float64
# PPFD_DIF           float64
# FAPAR              float64
# ZL                 float64
# dtype: object

# %%
# US_Var_nan['USTAR'].hist()
# Out:
# array(['TIMESTAMP_START', 'TIMESTAMP_END', 'USTAR', 'TA', 'WD', 'WS',
#        'NEE_PI', 'FC', 'SC', 'H', 'SH', 'LE', 'SLE', 'G', 'TS_1', 'TS_2',
#        'P', 'RH', 'PA', 'CO2_1', 'CO2_2', 'VPD_PI', 'SWC_1', 'SWC_2',
#        'NETRAD', 'PPFD_IN', 'SW_IN', 'SW_DIF', 'PPFD_OUT', 'SW_OUT',
#        'LW_IN', 'LW_OUT', 'H2O', 'RECO_PI', 'APAR', 'PPFD_DIF', 'FAPAR',
#        'ZL'], dtype=object)

# %%
plt.scatter(US_Var_nan["TA"], US_Var_nan["FC"])
